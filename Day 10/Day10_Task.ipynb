# %%
import numpy as np

arr = np.random.randint(1,100,20)

print(arr,"\n")

print("Mean :",np.mean(arr),"\n")

print("Median :",np.median(arr),"\n")

print("Max :",np.max(arr),"\n")

print("Min :",np.min(arr),"\n")

print("Standard Deviation :",np.std(arr),"\n")

print("Variance :",np.var(arr),"\n")

print("Elements Greter than Mean :","\n")
print(arr[arr>np.mean(arr)],"\n")

print("Sorted :",np.sort(arr),"\n")

print("Unique :",np.unique(arr),"\n")

print("Cumulative Sum :",np.cumsum(arr))
# Out:
# [15 60 52 66 84 22 91 18 71  8 85 70  4  6 52 83 35 10 18 70]
#
# Mean : 46.0
#
# Median : 52.0
#
# Max : 91
#
# Min : 4
#
# Standard Deviation : 30.111459612579395
#
# Variance : 906.7
#
# Elements Greter than Mean :
#
# [60 52 66 84 91 71 85 70 52 83 70]
#
# Sorted : [ 4  6  8 10 15 18 18 22 35 52 52 60 66 70 70 71 83 84 85 91]
#
# Unique : [ 4  6  8 10 15 18 22 35 52 60 66 70 71 83 84 85 91]
#
# Cumulative Sum : [ 15  75 127 193 277 299 390 408 479 487 572 642 646 652 704 787 822 832
#  850 920]
