# %%
#Q1: Import pandas and create a Series from a Python list with custom index labels.

import numpy as np
import pandas as pd

marks = [80,86,96,89,78,90]

series = pd.Series(marks,index =["A","B","C","D","E","F"])

series
# Out:
# A    80
# B    86
# C    96
# D    89
# E    78
# F    90
# dtype: int64

# %%
#Q2: Create a DataFrame from a dictionary containing columns: Name, Age, City, Salary (5 rows).

data = {
    "Name":("Vaishnavi","Rohit","Ganesh","Siddhesh","Aditya"),
    "Age" :(22,23,21,22,23),
    "City" : ("Pune","Pune","Jalna","Pune","Daund"),
    "Salary" : (88000,80000,76000,79000,80500)

}

data = pd.DataFrame(data)

data
# Out:
#         Name  Age   City  Salary
# 0  Vaishnavi   22   Pune   88000
# 1      Rohit   23   Pune   80000
# 2     Ganesh   21  Jalna   76000
# 3   Siddhesh   22   Pune   79000
# 4     Aditya   23  Daund   80500

# %%
#Q3: Load a CSV file into a DataFrame using pd.read_csv() and display the first 5 and last 5 rows.

data = pd.read_csv(r"C:\Users\Dell\OneDrive\Desktop\Data Analyst 2.0\Python Projects\Day 11\employees_100.csv")

# %%
data
# Out:
#    EmployeeID          Name Department  Age  Salary        City
# 0        E001    Employee 1         HR   23   30500        Pune
# 1        E002    Employee 2         IT   24   31000      Mumbai
# 2        E003    Employee 3    Finance   25   31500      Nashik
# 3        E004    Employee 4      Sales   26   32000      Nagpur
# 4        E005    Employee 5  Marketing   27   32500  Aurangabad
# ..        ...           ...        ...  ...     ...         ...
# 95       E096   Employee 96         HR   23   78000        Pune
# 96       E097   Employee 97         IT   24   78500      Mumbai
# 97       E098   Employee 98    Finance   25   79000      Nashik
# 98       E099   Employee 99      Sales   26   79500      Nagpur
# 99       E100  Employee 100  Marketing   27   80000  Aurangabad
#
# [100 rows x 6 columns]

# %%
(data.head())
# Out:
#   EmployeeID        Name Department  Age  Salary        City
# 0       E001  Employee 1         HR   23   30500        Pune
# 1       E002  Employee 2         IT   24   31000      Mumbai
# 2       E003  Employee 3    Finance   25   31500      Nashik
# 3       E004  Employee 4      Sales   26   32000      Nagpur
# 4       E005  Employee 5  Marketing   27   32500  Aurangabad

# %%
data.tail()
# Out:
#    EmployeeID          Name Department  Age  Salary        City
# 95       E096   Employee 96         HR   23   78000        Pune
# 96       E097   Employee 97         IT   24   78500      Mumbai
# 97       E098   Employee 98    Finance   25   79000      Nashik
# 98       E099   Employee 99      Sales   26   79500      Nagpur
# 99       E100  Employee 100  Marketing   27   80000  Aurangabad

# %%
#Q4: Display the shape, columns, dtypes, and summary statistics (describe()) of a DataFrame.

data.shape
# Out:
# (100, 6)

# %%
data.columns
# Out:
# Index(['EmployeeID', 'Name', 'Department', 'Age', 'Salary', 'City'], dtype='object')

# %%
data.dtypes
# Out:
# EmployeeID    object
# Name          object
# Department    object
# Age            int64
# Salary         int64
# City          object
# dtype: object

# %%
data.describe()
# Out:
#               Age        Salary
# count  100.000000    100.000000
# mean    30.700000  55250.000000
# std      5.533187  14505.745988
# min     22.000000  30500.000000
# 25%     26.000000  42875.000000
# 50%     30.500000  55250.000000
# 75%     35.250000  67625.000000
# max     40.000000  80000.000000

# %%
#Q5: Select a single column and multiple columns from a DataFrame.

data["Name"]
# Out:
# 0       Employee 1
# 1       Employee 2
# 2       Employee 3
# 3       Employee 4
# 4       Employee 5
#           ...
# 95     Employee 96
# 96     Employee 97
# 97     Employee 98
# 98     Employee 99
# 99    Employee 100
# Name: Name, Length: 100, dtype: object

# %%
data[["Name","Age","Salary"]]
# Out:
#             Name  Age  Salary
# 0     Employee 1   23   30500
# 1     Employee 2   24   31000
# 2     Employee 3   25   31500
# 3     Employee 4   26   32000
# 4     Employee 5   27   32500
# ..           ...  ...     ...
# 95   Employee 96   23   78000
# 96   Employee 97   24   78500
# 97   Employee 98   25   79000
# 98   Employee 99   26   79500
# 99  Employee 100   27   80000
#
# [100 rows x 3 columns]

# %%
#Q6: Select rows using loc[] (label-based) and iloc[] (position-based) indexing.

data.head()
# Out:
#   EmployeeID        Name Department  Age  Salary        City
# 0       E001  Employee 1         HR   23   30500        Pune
# 1       E002  Employee 2         IT   24   31000      Mumbai
# 2       E003  Employee 3    Finance   25   31500      Nashik
# 3       E004  Employee 4      Sales   26   32000      Nagpur
# 4       E005  Employee 5  Marketing   27   32500  Aurangabad

# %%
data.loc[0:5]
# Out:
#   EmployeeID        Name Department  Age  Salary        City
# 0       E001  Employee 1         HR   23   30500        Pune
# 1       E002  Employee 2         IT   24   31000      Mumbai
# 2       E003  Employee 3    Finance   25   31500      Nashik
# 3       E004  Employee 4      Sales   26   32000      Nagpur
# 4       E005  Employee 5  Marketing   27   32500  Aurangabad
# 5       E006  Employee 6         HR   28   33000        Pune

# %%
data.loc[2:8,["Name","Age","Department"]]
# Out:
#          Name  Age Department
# 2  Employee 3   25    Finance
# 3  Employee 4   26      Sales
# 4  Employee 5   27  Marketing
# 5  Employee 6   28         HR
# 6  Employee 7   29         IT
# 7  Employee 8   30    Finance
# 8  Employee 9   31      Sales

# %%
data.iloc[0:5]
# Out:
#   EmployeeID        Name Department  Age  Salary        City
# 0       E001  Employee 1         HR   23   30500        Pune
# 1       E002  Employee 2         IT   24   31000      Mumbai
# 2       E003  Employee 3    Finance   25   31500      Nashik
# 3       E004  Employee 4      Sales   26   32000      Nagpur
# 4       E005  Employee 5  Marketing   27   32500  Aurangabad

# %%
data.iloc[0:6,1:5]
# Out:
#          Name Department  Age  Salary
# 0  Employee 1         HR   23   30500
# 1  Employee 2         IT   24   31000
# 2  Employee 3    Finance   25   31500
# 3  Employee 4      Sales   26   32000
# 4  Employee 5  Marketing   27   32500
# 5  Employee 6         HR   28   33000

# %%
#Q7: Add a new calculated column to a DataFrame (e.g., Bonus = 10% of Salary).

data["Bonus"] = data["Salary"] * 0.10

data.columns

data.head()
# Out:
#   EmployeeID        Name Department  Age  Salary        City   Bonus
# 0       E001  Employee 1         HR   23   30500        Pune  3050.0
# 1       E002  Employee 2         IT   24   31000      Mumbai  3100.0
# 2       E003  Employee 3    Finance   25   31500      Nashik  3150.0
# 3       E004  Employee 4      Sales   26   32000      Nagpur  3200.0
# 4       E005  Employee 5  Marketing   27   32500  Aurangabad  3250.0

# %%
#Q8: Rename one or more column names in a DataFrame using rename().

data.rename(columns = {"Salary" : "Monthly Salary"},inplace=True)

data
# Out:
#    EmployeeID          Name Department  Age  Monthly Salary        City  \
# 0        E001    Employee 1         HR   23           30500        Pune
# 1        E002    Employee 2         IT   24           31000      Mumbai
# 2        E003    Employee 3    Finance   25           31500      Nashik
# 3        E004    Employee 4      Sales   26           32000      Nagpur
# 4        E005    Employee 5  Marketing   27           32500  Aurangabad
# ..        ...           ...        ...  ...             ...         ...
# 95       E096   Employee 96         HR   23           78000        Pune
# 96       E097   Employee 97         IT   24           78500      Mumbai
# 97       E098   Employee 98    Finance   25           79000      Nashik
# 98       E099   Employee 99      Sales   26           79500      Nagpur
# 99       E100  Employee 100  Marketing   27           80000  Aurangabad
#
#      Bonus
# 0   3050.0
# 1   3100.0
# 2   3150.0
# 3   3200.0
# 4   3250.0
# ..     ...
# 95  7800.0
# 96  7850.0
# 97  7900.0
# 98  7950.0
# 99  8000.0
#
# [100 rows x 7 columns]

# %%
data.rename(columns={
    "Name" : "Emp_Name",
    "Age" : "Emp_Age"
},inplace=True)

# %%
data
# Out:
#    EmployeeID      Emp_Name Department  Emp_Age  Monthly Salary        City  \
# 0        E001    Employee 1         HR       23           30500        Pune
# 1        E002    Employee 2         IT       24           31000      Mumbai
# 2        E003    Employee 3    Finance       25           31500      Nashik
# 3        E004    Employee 4      Sales       26           32000      Nagpur
# 4        E005    Employee 5  Marketing       27           32500  Aurangabad
# ..        ...           ...        ...      ...             ...         ...
# 95       E096   Employee 96         HR       23           78000        Pune
# 96       E097   Employee 97         IT       24           78500      Mumbai
# 97       E098   Employee 98    Finance       25           79000      Nashik
# 98       E099   Employee 99      Sales       26           79500      Nagpur
# 99       E100  Employee 100  Marketing       27           80000  Aurangabad
#
#      Bonus
# 0   3050.0
# 1   3100.0
# 2   3150.0
# 3   3200.0
# 4   3250.0
# ..     ...
# 95  7800.0
# 96  7850.0
# 97  7900.0
# 98  7950.0
# 99  8000.0
#
# [100 rows x 7 columns]

# %%
#Q9: Sort a DataFrame by a single column and by multiple columns.

data.sort_values(by="Monthly Salary")
# Out:
#    EmployeeID      Emp_Name Department  Emp_Age  Monthly Salary        City  \
# 0        E001    Employee 1         HR       23           30500        Pune
# 1        E002    Employee 2         IT       24           31000      Mumbai
# 2        E003    Employee 3    Finance       25           31500      Nashik
# 3        E004    Employee 4      Sales       26           32000      Nagpur
# 4        E005    Employee 5  Marketing       27           32500  Aurangabad
# ..        ...           ...        ...      ...             ...         ...
# 95       E096   Employee 96         HR       23           78000        Pune
# 96       E097   Employee 97         IT       24           78500      Mumbai
# 97       E098   Employee 98    Finance       25           79000      Nashik
# 98       E099   Employee 99      Sales       26           79500      Nagpur
# 99       E100  Employee 100  Marketing       27           80000  Aurangabad
#
#      Bonus
# 0   3050.0
# 1   3100.0
# 2   3150.0
# 3   3200.0
# 4   3250.0
# ..     ...
# 95  7800.0
# 96  7850.0
# 97  7900.0
# 98  7950.0
# 99  8000.0
#
# [100 rows x 7 columns]

# %%
data.sort_values(by=["Monthly Salary","Emp_Age","Bonus"])
# Out:
#    EmployeeID      Emp_Name Department  Emp_Age  Monthly Salary        City  \
# 0        E001    Employee 1         HR       23           30500        Pune
# 1        E002    Employee 2         IT       24           31000      Mumbai
# 2        E003    Employee 3    Finance       25           31500      Nashik
# 3        E004    Employee 4      Sales       26           32000      Nagpur
# 4        E005    Employee 5  Marketing       27           32500  Aurangabad
# ..        ...           ...        ...      ...             ...         ...
# 95       E096   Employee 96         HR       23           78000        Pune
# 96       E097   Employee 97         IT       24           78500      Mumbai
# 97       E098   Employee 98    Finance       25           79000      Nashik
# 98       E099   Employee 99      Sales       26           79500      Nagpur
# 99       E100  Employee 100  Marketing       27           80000  Aurangabad
#
#      Bonus
# 0   3050.0
# 1   3100.0
# 2   3150.0
# 3   3200.0
# 4   3250.0
# ..     ...
# 95  7800.0
# 96  7850.0
# 97  7900.0
# 98  7950.0
# 99  8000.0
#
# [100 rows x 7 columns]

# %%
#Q10: Use info() to check data types and non-null counts of every column.

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   EmployeeID      100 non-null    object
#  1   Emp_Name        100 non-null    object
#  2   Department      100 non-null    object
#  3   Emp_Age         100 non-null    int64
#  4   Monthly Salary  100 non-null    int64
#  5   City            100 non-null    object
#  6   Bonus           100 non-null    float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 5.6+ KB

# %%
#Q11: Filter rows in a DataFrame where a column value meets a condition (e.g., Age > 25)

data = data[data["Emp_Age"] > 25]

data
# Out:
#    EmployeeID      Emp_Name Department  Emp_Age  Monthly Salary        City  \
# 3        E004    Employee 4      Sales       26           32000      Nagpur
# 4        E005    Employee 5  Marketing       27           32500  Aurangabad
# 5        E006    Employee 6         HR       28           33000        Pune
# 6        E007    Employee 7         IT       29           33500      Mumbai
# 7        E008    Employee 8    Finance       30           34000      Nashik
# ..        ...           ...        ...      ...             ...         ...
# 91       E092   Employee 92         IT       38           76000      Mumbai
# 92       E093   Employee 93    Finance       39           76500      Nashik
# 93       E094   Employee 94      Sales       40           77000      Nagpur
# 98       E099   Employee 99      Sales       26           79500      Nagpur
# 99       E100  Employee 100  Marketing       27           80000  Aurangabad
#
#      Bonus
# 3   3200.0
# 4   3250.0
# 5   3300.0
# 6   3350.0
# 7   3400.0
# ..     ...
# 91  7600.0
# 92  7650.0
# 93  7700.0
# 98  7950.0
# 99  8000.0
#
# [77 rows x 7 columns]

# %%
#Q12: Filter rows using multiple conditions combined with AND (&) and OR (|).



print(data[(data["Emp_Age"] > 25) & (data["Monthly Salary"] > 35000)])
# Out:
#    EmployeeID      Emp_Name Department  Emp_Age  Monthly Salary        City  \
# 10       E011   Employee 11         HR       33           35500        Pune
# 11       E012   Employee 12         IT       34           36000      Mumbai
# 12       E013   Employee 13    Finance       35           36500      Nashik
# 13       E014   Employee 14      Sales       36           37000      Nagpur
# 14       E015   Employee 15  Marketing       37           37500  Aurangabad
# ..        ...           ...        ...      ...             ...         ...
# 91       E092   Employee 92         IT       38           76000      Mumbai
# 92       E093   Employee 93    Finance       39           76500      Nashik
# 93       E094   Employee 94      Sales       40           77000      Nagpur
# 98       E099   Employee 99      Sales       26           79500      Nagpur
# 99       E100  Employee 100  Marketing       27           80000  Aurangabad
#
#      Bonus
# 10  3550.0
# 11  3600.0
# 12  3650.0
# 13  3700.0
# 14  3750.0
# ..     ...
# 91  7600.0
# 92  7650.0
# 93  7700.0
# 98  7950.0
# 99  8000.0
#
# [70 rows x 7 columns]

# %%
print(data[(data["Department"] == "IT") | (data["City"] == "Pune")])
# Out:
#    EmployeeID     Emp_Name Department  Emp_Age  Monthly Salary    City   Bonus
# 5        E006   Employee 6         HR       28           33000    Pune  3300.0
# 6        E007   Employee 7         IT       29           33500  Mumbai  3350.0
# 10       E011  Employee 11         HR       33           35500    Pune  3550.0
# 11       E012  Employee 12         IT       34           36000  Mumbai  3600.0
# 15       E016  Employee 16         HR       38           38000    Pune  3800.0
# 16       E017  Employee 17         IT       39           38500  Mumbai  3850.0
# 25       E026  Employee 26         HR       29           43000    Pune  4300.0
# 26       E027  Employee 27         IT       30           43500  Mumbai  4350.0
# 30       E031  Employee 31         HR       34           45500    Pune  4550.0
# 31       E032  Employee 32         IT       35           46000  Mumbai  4600.0
# 35       E036  Employee 36         HR       39           48000    Pune  4800.0
# 36       E037  Employee 37         IT       40           48500  Mumbai  4850.0
# 41       E042  Employee 42         IT       26           51000  Mumbai  5100.0
# 45       E046  Employee 46         HR       30           53000    Pune  5300.0
# 46       E047  Employee 47         IT       31           53500  Mumbai  5350.0
# 50       E051  Employee 51         HR       35           55500    Pune  5550.0
# 51       E052  Employee 52         IT       36           56000  Mumbai  5600.0
# 55       E056  Employee 56         HR       40           58000    Pune  5800.0
# 60       E061  Employee 61         HR       26           60500    Pune  6050.0
# 61       E062  Employee 62         IT       27           61000  Mumbai  6100.0
# 65       E066  Employee 66         HR       31           63000    Pune  6300.0
# 66       E067  Employee 67         IT       32           63500  Mumbai  6350.0
# 70       E071  Employee 71         HR       36           65500    Pune  6550.0
# 71       E072  Employee 72         IT       37           66000  Mumbai  6600.0
# 80       E081  Employee 81         HR       27           70500    Pune  7050.0
# 81       E082  Employee 82         IT       28           71000  Mumbai  7100.0
# 85       E086  Employee 86         HR       32           73000    Pune  7300.0
# 86       E087  Employee 87         IT       33           73500  Mumbai  7350.0
# 90       E091  Employee 91         HR       37           75500    Pune  7550.0
# 91       E092  Employee 92         IT       38           76000  Mumbai  7600.0

# %%
#Q13: Drop a column and drop a row from a DataFrame using drop(). 

data = data.drop("Bonus",axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[80], line 3
#       1 #Q13: Drop a column and drop a row from a DataFrame using drop().
# ----> 3 data = data.drop("Bonus",axis = 1)
#       5 data.head
#
# File c:\Users\Dell\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# File c:\Users\Dell\anaconda3\Lib\site-packages\pandas\core\generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 for axis, labels in axes.items():
#    4809     if labels is not None:
# -> 4810         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4812 if inplace:
#    4813     self._update_inplace(obj)
#
# File c:\Users\Dell\anaconda3\Lib\site-packages\pandas\core\generic.py:4852, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4850         new_axis = axis.drop(labels, level=level, errors=errors)
#    4851     else:
# -> 4852         new_axis = axis.drop(labels, errors=errors)
#    4853     indexer = axis.get_indexer(new_axis)
#    4855 # Case for non-unique axis
#    4856 else:
#
# File c:\Users\Dell\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['Bonus'] not found in axis"

# %%
data
# Out:
#    EmployeeID      Emp_Name Department  Emp_Age  Monthly Salary        City
# 3        E004    Employee 4      Sales       26           32000      Nagpur
# 4        E005    Employee 5  Marketing       27           32500  Aurangabad
# 5        E006    Employee 6         HR       28           33000        Pune
# 6        E007    Employee 7         IT       29           33500      Mumbai
# 7        E008    Employee 8    Finance       30           34000      Nashik
# ..        ...           ...        ...      ...             ...         ...
# 91       E092   Employee 92         IT       38           76000      Mumbai
# 92       E093   Employee 93    Finance       39           76500      Nashik
# 93       E094   Employee 94      Sales       40           77000      Nagpur
# 98       E099   Employee 99      Sales       26           79500      Nagpur
# 99       E100  Employee 100  Marketing       27           80000  Aurangabad
#
# [77 rows x 6 columns]

# %%
data = data.drop(3)

# %%
data
# Out:
#    EmployeeID      Emp_Name Department  Emp_Age  Monthly Salary        City
# 4        E005    Employee 5  Marketing       27           32500  Aurangabad
# 5        E006    Employee 6         HR       28           33000        Pune
# 6        E007    Employee 7         IT       29           33500      Mumbai
# 7        E008    Employee 8    Finance       30           34000      Nashik
# 8        E009    Employee 9      Sales       31           34500      Nagpur
# ..        ...           ...        ...      ...             ...         ...
# 91       E092   Employee 92         IT       38           76000      Mumbai
# 92       E093   Employee 93    Finance       39           76500      Nashik
# 93       E094   Employee 94      Sales       40           77000      Nagpur
# 98       E099   Employee 99      Sales       26           79500      Nagpur
# 99       E100  Employee 100  Marketing       27           80000  Aurangabad
#
# [76 rows x 6 columns]

# %%
#Q14: Reset the index of a DataFrame after filtering, using reset_index().\

data.reset_index()
# Out:
#     index EmployeeID      Emp_Name Department  Emp_Age  Monthly Salary  \
# 0       4       E005    Employee 5  Marketing       27           32500
# 1       5       E006    Employee 6         HR       28           33000
# 2       6       E007    Employee 7         IT       29           33500
# 3       7       E008    Employee 8    Finance       30           34000
# 4       8       E009    Employee 9      Sales       31           34500
# ..    ...        ...           ...        ...      ...             ...
# 71     91       E092   Employee 92         IT       38           76000
# 72     92       E093   Employee 93    Finance       39           76500
# 73     93       E094   Employee 94      Sales       40           77000
# 74     98       E099   Employee 99      Sales       26           79500
# 75     99       E100  Employee 100  Marketing       27           80000
#
#           City
# 0   Aurangabad
# 1         Pune
# 2       Mumbai
# 3       Nashik
# 4       Nagpur
# ..         ...
# 71      Mumbai
# 72      Nashik
# 73      Nagpur
# 74      Nagpur
# 75  Aurangabad
#
# [76 rows x 7 columns]

# %%
#Q15: Convert a DataFrame column to a NumPy array and to a Python list.

salary = data["Monthly Salary"].to_numpy()

salary2 = data["Monthly Salary"].to_list()

# %%
salary
# Out:
# array([32500, 33000, 33500, 34000, 34500, 35000, 35500, 36000, 36500,
#        37000, 37500, 38000, 38500, 39000, 41500, 42000, 42500, 43000,
#        43500, 44000, 44500, 45000, 45500, 46000, 46500, 47000, 47500,
#        48000, 48500, 51000, 51500, 52000, 52500, 53000, 53500, 54000,
#        54500, 55000, 55500, 56000, 56500, 57000, 57500, 58000, 60500,
#        61000, 61500, 62000, 62500, 63000, 63500, 64000, 64500, 65000,
#        65500, 66000, 66500, 67000, 67500, 70000, 70500, 71000, 71500,
#        72000, 72500, 73000, 73500, 74000, 74500, 75000, 75500, 76000,
#        76500, 77000, 79500, 80000])

# %%
type(salary)
# Out:
# numpy.ndarray

# %%
salary2
# Out:
# [32500,
#  33000,
#  33500,
#  34000,
#  34500,
#  35000,
#  35500,
#  36000,
#  36500,
#  37000,
#  37500,
#  38000,
#  38500,
#  39000,
#  41500,
#  42000,
#  42500,
#  43000,
#  43500,
#  44000,
#  44500,
#  45000,
#  45500,
#  46000,
#  46500,
#  47000,
#  47500,
#  48000,
#  48500,
#  51000,
#  51500,
#  52000,
#  52500,
#  53000,
#  53500,
#  54000,
#  54500,
#  55000,
#  55500,
#  56000,
#  56500,
#  57000,
#  57500,
#  58000,
#  60500,
#  61000,
#  61500,
#  62000,
#  62500,
#  63000,
#  63500,
#  64000,
#  64500,
#  65000,
#  65500,
#  66000,
#  66500,
#  67000,
#  67500,
#  70000,
#  70500,
#  71000,
#  71500,
#  72000,
#  72500,
#  73000,
#  73500,
#  74000,
#  74500,
#  75000,
#  75500,
#  76000,
#  76500,
#  77000,
#  79500,
#  80000]

# %%
type(salary2)
# Out:
# list
