# %%
#Q1: Check if a number is positive, negative, or zero

num = float(input("Enter Number :"))

print("Number :",num)

if num < 0 :
    print("Number is Negative :")

elif num == 0 :
    print("Number is Zero :")

else:
    print("Number is Positive :")
# Out:
# Number : -343.0
# Number is Negative :

# %%
#Q2: Check eligibility to vote (age >= 18).

age = int(input("Enter your Age :"))

print("Your Age is :",age)

if age < 18 :
    print("You are not eligibel to vote.")

else :
    print("You are eligible for vote.")
# Out:
# Your Age is : 17
# You are not eligibel to vote.

# %%
#Q3: Find the largest of three numbers using if-elif-else.

num1 = float(input("Enter Num1 :"))

print("Num_1 :",num1)

num2 = float(input("Enter Num2 :"))

print("Num_2 :",num2)

num3 = float(input("Enter Num3 :"))

print("Num_3 :",num3)

if num1 > num2 and num1 > num3 :
    print("Num_1 is Largest Number which is :",num1)

elif num2 > num1 and num2 > num3 :
    print("Num_2 is Largest Number which is :",num2)

elif num1 == num2 and num2 == num3 :
    print("All numbers are equal :",num1,"=",num2,"=",num3)

else:
    print("Num_3 is Largest which is :",num3)
# Out:
# Num_1 : 66.0
# Num_2 : 66.0
# Num_3 : 66.0
# All numbers are equal : 66.0 = 66.0 = 66.0

# %%
#Q4: Assign grades based on marks: A (90-100), B (80-89), C (70-79), D (60-69), F (<60).

marks = float(input("Enter Marks :"))

print("marks :",marks)

if marks >= 90 and marks <= 100 :
    print("Grade A")

elif marks >= 80 and marks <= 89 :
    print("Grade B")

elif marks >= 70 and marks <= 79 :
    print("Grade C")

elif marks >= 60 and marks <= 69 :
    print("Grade D")

else:
    print("Grade F")
# Out:
# marks : 70.0
# Grade C

# %%
#Q5: Check if a year is a leap year.
"""
If the year is divisible by 400, it is a leap year.
Or, if it is divisible by 4 but not divisible by 100, it is a leap year.
"""

year = int(input("Enter a year :"))

print("Year :",year)

if (year % 400 == 0 ) or (year % 4 == 0 and year % 100 != 0):
    print("This year is a Leap Year.")

else:
    print("This year is not a Leap Year.")
# Out:
# Year : 2025
# This year is not a Leap Year.

# %%
#Q6: Check if a number is between 1 and 100 (inclusive).

number = int(input("Enter a Number :"))

print("Number is :",number)

if number >= 1 and number <= 100 :
    print("Number is between 1 and 100.")

else:
    print("Number is not between 1 and 100.")
# Out:
# Number is : 54
# Number is between 1 and 100.

# %%
#Q7: Check if a number is even/odd AND positive/negative

number = int(input("Enter a Number :"))

if number >= 1 :
    print("Number is Positive.")

elif number < 0 :
    print("Number is Negative.")

else:
    print("Number is Zero")
# Out:
# Number is Positive.

# %%
number = int(input("Enter a Number :"))

if number % 2 == 0 :
    print("Number is Even.")

else:
    print("Number is Odd")
# Out:
# Number is Even.

# %%
#Q9: Check if a person can get a loan (age >= 21 AND income >= 100000).

age = float(input("Enter Your Age :"))

income = float(input("Enter Your Income :"))

print("Your Age is :",age)

print("Your Income is :",income)

if age >= 21 and income >= 100000 :
    print("You can get Loan.")

else:
    print("You can't get Loan.")
# Out:
# Your Age is : 20.0
# Your Income is : 200000.0
# You can't get Loan.

# %%
#Q10: Determine if a triangle is valid given three sides.

"""
A triangle is valid only if the sum of any two sides is greater than the third side:

Side1 + Side2 > Side3
Side1 + Side3 > Side2
Side2 + Side3 > Side1
"""

Side1= float(input("Enter First side :"))

Side2= float(input("Enter second side :"))

Side3= float(input("Enter third side :"))

if(Side1 + Side2 > Side3) and (Side1 + Side3 > Side2) and (Side2 + Side3 > Side1):
    print("It is a valid triangle.")

else:
    print("It is not a valid triangle.")
# Out:
# It is not a valid triangle.

# %%
#Q11: Check if a number is divisible by both 3 and 5.

num = int(input("Enter a Number :"))

if num % 3 == 0 and num % 5 == 0:
    print("Number is divisible by both 3 & 5 :")

else:
    print("Number is not divisible by both 3 & 5 :")
# Out:
# Number is not divisible by both 3 & 5 :

# %%
#Q12: Determine if a person is eligible for senior citizen discount (age >= 60).

age = int(input("Enter Your Age :"))

print("Your Age is :",age)

if age >= 60 :
    print("You are eligible for senior citizen discount.")

else:
    print("YYou are not eligible for senior citizen discount.")
# Out:
# Your Age is : 60.0
# You are eligible for senior citizen discount.

# %%
#Q14: Find the maximum temperature of the day (given morning, afternoon, evening temps).

morning = float(input("Enter Morning Temprature :"))

print("Morning Temprature is:",morning)

afternoon = float(input("Enter Afternoon Temprature :"))

print("afternoon Temprature is:",afternoon)

evening = float(input("Enter Evening Temprature :"))

print("Evening Temprature is:",evening)

if morning > afternoon and morning > evening:
    print("Morning Temprature is Maximum which is :",morning)

elif afternoon > morning and afternoon > evening:
    print("Afternoon Temprature is Maximum which is :",afternoon)

else:
    print("Evening Temprature is Maximum which is :",evening)
# Out:
# Morning Temprature is: 34.0
# afternoon Temprature is: 35.0
# Evening Temprature is: 40.0
# Evening Temprature is Maximum which is : 40.0

# %%
#Q15: Check if a number is a perfect square.

number = int(input("Enter Number :"))

if(number**0.5) * (number**0.5) == number:
    print("The Number is a perfect square :",number)

else:
    print("The Number is not a perfect square :",number)
# Out:
# The Number is not a perfect square : 5

# %%
#Q16: Determine overtime payment: if hours > 8, extra 1.5x pay.

hours = float(input("Enter your Working Hours :"))

rate = float(input("Enter Rate per Hour :"))

if hours > 8 :
    pay = (8 * rate) + ((hours - 8)* 1.5 * rate)

else:
    pay = (hours * rate)

print("Total pay is :",pay)
# Out:
# Total pay is : 1100.0

# %%
#Q19: Check if a person qualifies for a scholarship (score >= 85 AND income <= 500000).

score = float(input("Enter Your Score :"))

income = float(input("Enter Your Income :"))

print("Your Score is :",score)

print("Your Income is :",income)

if score >= 85 and income <= 500000 :
    print("You are qualified for scolerhip.")

else:
    print("You are not qualified for scolership.")
# Out:
# Your Score is : 84.0
# Your Income is : 400000.0
# You are not qualified for scolership.

# %%
#Q20: Assign T-shirt size: XS (< 35), S (35-40), M (40-50), L (50-60), XL (> 60).

size = int(input("Enter your Chest Size :"))

if size < 35 :
    print("Your size is XS")

elif size >= 35 and size < 40:
    print("Your size is S")

elif size >= 40 and size < 50:
    print("Your size is M")

elif size >= 50 and size < 60:
    print("Your size is L")

else:
    print("Your size is XL")
# Out:
# Your size is M
